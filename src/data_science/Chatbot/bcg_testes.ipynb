# %% [markdown]
# ### imports

# %%
# !pip install langchain -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 344.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.7 MB/s eta 0:00:00

# %%
# !pip install langchain_community -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.2 MB/s eta 0:00:00

# %%
# !pip install langchain_openai -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.5/383.5 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 6.4 MB/s eta 0:00:00

# %%
# %pip install --upgrade --quiet  pygithub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 32.5 MB/s eta 0:00:00

# %%
# %pip install -qU duckduckgo-search langchain-community -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 39.0 MB/s eta 0:00:00

# %%
# !pip install chromadb -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.0/604.0 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 27.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-cpu -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 19.2 MB/s eta 0:00:00

# %%
#Todos os imports aqui
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain_openai import OpenAIEmbeddings
from langchain.embeddings import CacheBackedEmbeddings
from langchain.storage import LocalFileStore
from langchain_community.vectorstores import FAISS
import requests
from langchain.agents import AgentExecutor, create_openai_functions_agent
from langchain_openai import ChatOpenAI
from langchain_community.tools import DuckDuckGoSearchResults
import os
import openai
from langchain.chains import LLMChain
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from langchain.prompts import PromptTemplate
from langchain.prompts import (
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
    AIMessagePromptTemplate,
    ChatPromptTemplate
)
from langchain_community.document_loaders.image import UnstructuredImageLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.callbacks import get_openai_callback
from langchain.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate
from langchain.prompts.example_selector import SemanticSimilarityExampleSelector
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain.chains import LLMChain
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate
from langchain.chains import TransformChain
import base64
from langchain.chains.transform import TransformChain
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI
from langchain import globals
from langchain_core.runnables import chain
from langchain_core.output_parsers import JsonOutputParser
#from langchain_core.pydantic_v1 import BaseModel, Field
from pydantic import BaseModel, Field
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain.memory import ChatMessageHistory
from langchain_core.prompts import MessagesPlaceholder
from IPython.display import display, Markdown
import matplotlib.image as mpimg
from langchain.agents import initialize_agent, Tool
from langchain.llms import OpenAI
from langchain.memory import ConversationBufferMemory
from scipy import stats
import os
import openai

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Exception in thread _colab_inspector_thread:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_debugpy.py", line 64, in inspector_thread
#     _variable_inspector.run(shell, time)
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_variable_inspector.py", line 27, in run
#     globals().clear()
# TypeError: 'module' object is not callable
# Mounted at /content/drive

# %%
#key
os.environ['OPENAI_API_KEY'] = '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'

# Use a chave a partir das variáveis de ambiente
api_key = os.getenv('OPENAI_API_KEY')

# Utilize a API com a chave
openai.api_key = api_key
client = openai.OpenAI(api_key=api_key)

# %%
os.environ["LANGCHAIN_TRACING_V2"]= "true"
os.environ["LANGCHAIN_ENDPOINT"]="https://api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"]="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"
os.environ["LANGCHAIN_PROJECT"]="testes_iniciais_bcg"

# %% [markdown]
# #Código

# %% [markdown]
# ##vector dp

# %%
import os
import faiss
from typing import List

# %%
# !pip install --quiet langchain_experimental -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 kB 13.3 MB/s eta 0:00:00

# %%
# %pip install --upgrade --quiet langchain-text-splitters tiktoken

# %%
with open('/content/plano-acao-adaptacao-climatica-nacional.txt', 'r',encoding='utf-8') as file:
    file_content = file.read()

# Now, file_content contains the entire content of the text file
print(file_content)
# Out:
# --- Page 1 ---
#
# 60 1. Histórico e contexto legal
# 61 A Política Nacional de Mudanças Climáticas - PNMC – (Lei nº 12.187, de 29 de
# 62 dezembro de 2009), traz amparo legal para a elaboração do Plano Nacional de
# 63 Adaptação à Mudança do Clima. Em seu inciso V, artigo 4º, a PNMC estabelece a
# 64 necessidade de implementação de medidas para promover a adaptação à mudança do
# 65 clima pelas três esferas da Federação. Determinações que prevejam diretrizes e
# 66 condutas gerais para todos os entes da Federação, a exemplo daquelas constantes
# 67 neste Plano, são norteadoras para a cooperação, direcionamento e alinhamento de
# 68 esforços de tais entes.
# 69 A PNMC também prevê como um dos seus instrumentos, o Plano Nacional
# 70 sobre Mudança do Clima. Este Plano propõe a elaboração do Plano Nacional de
# 71 Adaptação, afirmando que o mesmo deve se somar às iniciativas e aos avanços de
# 72 mitigação dos impactos das mudanças climáticas realizados até o momento, a fim de
# ...

# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
# %%time
text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    encoding_name="cl100k_base", chunk_size=700, chunk_overlap=200
)
docs = text_splitter.split_text(file_content)
print(f'o documento foi dividido em {len(docs)} chunks')
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 716, which is longer than the specified 700
# WARNING:langchain_text_splitters.base:Created a chunk of size 735, which is longer than the specified 700
# WARNING:langchain_text_splitters.base:Created a chunk of size 879, which is longer than the specified 700
# WARNING:langchain_text_splitters.base:Created a chunk of size 877, which is longer than the specified 700
# WARNING:langchain_text_splitters.base:Created a chunk of size 1125, which is longer than the specified 700
# WARNING:langchain_text_splitters.base:Created a chunk of size 784, which is longer than the specified 700
# WARNING:langchain_text_splitters.base:Created a chunk of size 704, which is longer than the specified 700
# WARNING:langchain_text_splitters.base:Created a chunk of size 781, which is longer than the specified 700
# WARNING:langchain_text_splitters.base:Created a chunk of size 726, which is longer than the specified 700
# ...

# %%
docs[5], len(docs[5])
# Out:
# ('--- Page 6 ---\n\nMudança do clima observada e futura\n162 emissões de gases de efeito estufa atingindo emissão zero por volta de 2070, podendo\n163 os processos de absorção de gases superar as emissões em algum momento. Nesse\n164 caso, os aumentos esperados da temperatura média terrestre seriam etontre 0,3 °C e\n165 1,7 º C de 2010 até 2100 e do nível do mar, entre 26 e 55 centímetros. Esse cenário,\n166 por ser considerado muito otimista, tem sido preterido nas atuais análises de projeção\n167 climáticas.\n168 O segundo cenário, RCP 4.5, supõe um armazenamento de 4,5 W/m2 e\n169 representa uma estabilização das emissões de gases de efeito estufa antes de 2100.\n170 Nesse caso, a temperatura terrestre aumentaria entre 1,1 °C e 2,6 °C e o nível do mar\n171 subiria entre 32 e 63 centímetros. Esse cenário tem sido um dos mais utilizados.\n172 O cenário RCP 6.0 supõe o armazenamento de 6,0 W/m2 com estabilização das\n173 emissões de gases de efeito estufa logo após 2100. O aumento da
# ...

# %%
len

# %%
total = 0
for doc in docs:
  print(f'len doc {len(doc)}')
  total += len(doc)
print(total)
total/(len(docs))
# Out:
# len doc 1725
# len doc 1290
# len doc 1717
# len doc 1883
# len doc 2100
# len doc 2079
# len doc 2307
# len doc 2022
# len doc 1027
# len doc 2240
# len doc 1592
# len doc 1892
# len doc 2189
# len doc 1300
# len doc 1578
# len doc 1443
# len doc 1603
# len doc 1691
# len doc 1910
# len doc 1453
# len doc 1843
# len doc 1999
# len doc 1767
# len doc 2003
# len doc 2117
# len doc 2041
# len doc 1290
# len doc 1748
# len doc 2100
# len doc 1801
# len doc 1723
# len doc 2085
# len doc 2268
# len doc 2193
# len doc 1916
# len doc 2153
# len doc 2043
# len doc 2245
# len doc 1983
# len doc 2200
# len doc 1978
# len doc 1950
# len doc 1905
# len doc 1846
# len doc 1832
# len doc 2164
# len doc 1871
# len doc 1220
# len doc 2442
# len doc 2523
# len doc 2234
# len doc 2371
# len doc 1993
# len doc 1699
# len doc 2101
# len doc 1894
# len doc 1437
# len doc 1948
# len doc 2313
# len doc 1877
# len doc 2208
# len doc 2098
# len doc 2149
# len doc 2056
# len doc 1891
# len doc 2081
# ...

# %%
def generate_embeddings(input: List[str], model='text-embedding-ada-002')-> List[float]:
    embedding = client.embeddings.create(
        model=model,
        input=input
    )
    total_tokens = embedding.usage.total_tokens
    embeddings = [data.embedding for data in embedding.data]
    return embedding.data[0].embedding

# %%
df = pd.DataFrame(docs, columns=["content"])
df["embedding"] = df["content"].apply(lambda x: generate_embeddings([x]))
df
# Out:
#                                                content  \
# 0    --- Page 1 ---\n\n60 1. Histórico e contexto l...
# 1    --- Page 2 ---\n\nHistórico e contexto legal\n...
# 2    --- Page 3 ---\n\n99 2. Mudança do clima obser...
# 3    --- Page 4 ---\n\nMudança do clima observada e...
# 4    --- Page 5 ---\n\nMudança do clima observada e...
# ..                                                 ...
# 376  --- Page 362 ---\n\nAnexo – Síntese das estrat...
# 377  Anexo – Síntese das estratégias setoriais e te...
# 378                                   --- Page 364 ---
# 379  6518 Glossário\n6519\n6520 ADAPTAÇÃO: o proces...
# 380  --- Page 365 ---\n\nGlossário\nocorrência pote...
#
#                                              embedding
# 0    [0.0023856612388044596, 0.0031755196396261454,...
# 1    [-0.0005016723298467696, -0.01000907365232706,...
# 2    [-0.00022179620282258838, -0.00811874493956565...
# 3    [-0.006590797565877438, 0.0033145395573228598,...
# ...

# %%
embedding_list = df["embedding"].tolist()

# %%
text_embeddings_pairs = list(zip(docs, embedding_list))

# %% [markdown]
# ##retriever

# %%
from langchain.vectorstores import FAISS
db = FAISS.from_embeddings(text_embeddings_pairs, embedding_list)
# Out:
# WARNING:langchain_community.vectorstores.faiss:`embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
import numpy as np
def _get_cos(vec_a: list, vec_b: list):
    vec_a = np.array(vec_a)
    vec_b = np.array(vec_b)
    return vec_a.dot(vec_b) / (np.linalg.norm(vec_a) * np.linalg.norm(vec_b))

# %%
def query_toEmbedding(query:str):
  embedding_vector = generate_embeddings(query)
  return embedding_vector
def retriever(query:str, k:int = 4, db = db):
  query_embeddings = query_toEmbedding(query = query)
  topk = db.similarity_search_by_vector(query_embeddings, k=k)
  return topk
def retriever_with_score(query:str, k:int = 4, db = db):
  topk = retriever(query, k, db)
  query_embeddings = query_toEmbedding(query=query)
  scores = []
  #results_with_scores = []
  for doc in topk:
      doc_content = doc.page_content
      matching_row = df[df["content"] == doc_content]  # Supondo que cada documento tenha um campo 'embedding'
      if not matching_row.empty:
            doc_embedding = matching_row.iloc[0]["embedding"]  # Acessa o primeiro resultado

            # Calcular a similaridade do cosseno entre o embedding da consulta e o documento
            score = _get_cos(query_embeddings, doc_embedding)
            scores.append(score)
      else:
          print(f"Documento não encontrado no DataFrame: {doc_content}")
      # Adicionar o documento e seu score à lista de resultados
      #results_with_scores.append((doc, score))

  return topk, scores

# %%
lk, sk = retriever_with_score("qual é o maior predio do brasil")

# %%
sk
# Out:
# [0.7734443456185949,
#  0.7710378715395105,
#  0.7691144601052301,
#  0.7687911019506907]

# %%
l = retriever("qual é o maior problema climatico do Brasil")
l[0].page_content, len(l)
# Out:
# ('--- Page 4 ---\n\nMudança do clima observada e futura\n121 Alguns possíveis impactos dessas alterações climáticas para o Brasil e América\n122 do Sul consistem na extinção de hábitats e de espécies, principalmente na região\n123 tropical; substituição de florestas tropicais por savanas e vegetação semiárida por\n124 árida; aumento de regiões em situação de estresse hídrico, ou seja, sem água\n125 suficiente para suprir as demandas da população e aumento de pragas em culturas\n126 agrícolas e de doenças, como a dengue e malária na população (PBMC, 2013).\n127 Os relatórios do PBMC e do IPCC referentes ao Grupo de Trabalho II (WGII, da\n128 sigla em inglês), são unânimes em revelar que a América do Sul e o Brasil já\n129 apresentam registros de mudanças do clima previstos em modelos climáticos. Esses\n130 registros afirmam que a América do Sul já enfrenta os seguintes efeitos significativos\n131 da mudança do clima:\n\uf0fc Aumento de temperatura de até 2,5ºC na região costeira do Br
# ...

# %% [markdown]
# ##Chain

# %%
model_name = 'gpt-4o-mini'
temperature = 0.5
max_tokens = None

# %%
model = ChatOpenAI(model = model_name, temperature = temperature, max_tokens = max_tokens )

# %%
def call_llm(query: str, model = model, k:int = 4, context = None, memory = None):
  if context == None:
    docs = retriever(query)
    context = [doc.page_content for doc in docs]   #rever isso pra implementar no grafo


  # Define a system prompt that guides the assistant to help a city planner with climate change-related planning
  # using official documents as context.
  if memory == None:
    memory = ' '
  system_prompt = (
          '''You are a helpful assistant, who will help a city planner on the theme of climate changes.
          Here is the chat memory, if it exists, use it:\n {memory}
          You will have official documents as context, use them to answer with quality and good foundation. \n
          contexte: \n {context}
      '''
      )

  # Create a SystemMessagePromptTemplate using the system_prompt.
  system_template = SystemMessagePromptTemplate.from_template(system_prompt)


  # Define a human prompt where the city planner provides a specific query for assistance.
  human_prompt = (
      '''I'm a city planner and want you assistance to do my planning on the climate changes.
      My job depends on this task. Here is my query: \n {query}'''
  )


  # Create a HumanMessagePromptTemplate using the human_prompt.
  human_template = HumanMessagePromptTemplate.from_template(human_prompt)

  # Combine the system and human prompts into a ChatPromptTemplate to guide the conversation.
  final_prompt = ChatPromptTemplate.from_messages(
    [
        system_template,
        human_template
    ]
  )

  # Create a chain that takes the final_prompt as input, uses the 'model' to process it, and parses the output with StrOutputParser.
  chain = (
      final_prompt  # Input prompt combining system and human messages
      | model       # Model processes the input prompt
      | StrOutputParser()  # Output is parsed as a string
  )
  # Execute the chain, using OpenAI's callback to track usage (like token count or cost).
  # The invoke method uses the 'context' and 'query' as inputs for the assistant to generate the response.

  output = chain.invoke({
      "context": context,  # Placeholder for the actual context (official documents, data, etc.)
      "query": query,    # Placeholder for the actual query from the city planner
      "memory": memory
  })
  return output

# %%
query = "Quais são as melhores práticas para mitigar os efeitos das ilhas de calor urbanas em nossa cidade?"
output, cb = call_llm(query)
output
# Out:
# 'Para mitigar os efeitos das ilhas de calor urbanas, é essencial adotar uma abordagem integrada que considere tanto o planejamento urbano quanto a implementação de políticas públicas eficazes. Aqui estão algumas das melhores práticas que podem ser implementadas:\n\n1. **Aumento da Vegetação Urbana**: O plantio de árvores e a criação de espaços verdes, como parques e jardins, ajudam a resfriar o ambiente. A vegetação proporciona sombra e evapotranspiração, reduzindo as temperaturas locais.\n\n2. **Telhados Verdes e Jardins Verticais**: Incentivar a instalação de telhados verdes e jardins verticais em edifícios pode aumentar a área verde da cidade e melhorar o isolamento térmico, reduzindo a temperatura interna dos edifícios.\n\n3. **Materiais de Construção Refletivos**: Utilizar materiais de construção que reflitam a luz solar, como telhas claras e pavimentos permeáveis, pode ajudar a reduzir a absorção de calor nas superfícies urbanas.\n\n4. **Planejamento de Espaços Públicos**: Proj
# ...

# %%
print(output)
# Out:
# Para mitigar os efeitos das ilhas de calor urbanas, é essencial adotar uma abordagem integrada que considere tanto o planejamento urbano quanto a implementação de políticas públicas eficazes. Aqui estão algumas das melhores práticas que podem ser implementadas:
#
# 1. **Aumento da Vegetação Urbana**: O plantio de árvores e a criação de espaços verdes, como parques e jardins, ajudam a resfriar o ambiente. A vegetação proporciona sombra e evapotranspiração, reduzindo as temperaturas locais.
#
# 2. **Telhados Verdes e Jardins Verticais**: Incentivar a instalação de telhados verdes e jardins verticais em edifícios pode aumentar a área verde da cidade e melhorar o isolamento térmico, reduzindo a temperatura interna dos edifícios.
#
# 3. **Materiais de Construção Refletivos**: Utilizar materiais de construção que reflitam a luz solar, como telhas claras e pavimentos permeáveis, pode ajudar a reduzir a absorção de calor nas superfícies urbanas.
#
# ...

# %% [markdown]
# #Evolução e possíveis usos

# %%
#REVER MINHAS ANOTAÇÕES E A ARQUITETURA QUE TINHA PENSADO

# %%
#Pesquisar nas anotações e fazer agentes ou tarefas lineares de passos:
#ex: agente que pesquisa sobre a cidade do usuário
#ex2: agente que pesquisa a query no google se nenhum dos contextos bate a treshold ou pede mais info ao usuário

#Prompt que trabalha com exemplos, pensar bem como
#ex 3
'''O usuário pede uma análise de dados climáticos.
O chatbot utiliza o agente de recuperação para obter dados relevantes e, em seguida, aciona um agente analítico para calcular tendências ou gerar gráficos.'''

# %% [markdown]
# ## agente que pesquisa sobre a cidade do usuário

# %%
#Posso fazer uma função que pede mais info caso ele escolha vectorsotre, mas os documentos não passam da treshold
from typing import Literal
class Initial_choice(BaseModel):
    """Route a user query to the most relevant datasource, the vectorstore or a web search."""

    datasource: Literal["vectorstore", "web_search"] = Field(
        ...,
        description="Given a user question choose to route it to web search or a vectorstore.",
    )

# %%
def router_func(query:str):
  system = """You are an expert at routing a user question to a vectorstore or web search.
  The vectorstore contains documents in portuguese related to climate plans for cities in Brazil.
  Use the vectorstore for questions on these topics. Otherwise, use web-search."""
  route_prompt = ChatPromptTemplate.from_messages(
      [
          ("system", system),
          ("human", "{query}"),
      ]
  )
  structured_model_router = model.with_structured_output(Initial_choice) #Will return or "vectorstore" or "web_search"
  question_router = route_prompt | structured_model_router
  return question_router.invoke({'query': query})

# %%
router_func(query)
# Out:
# Initial_choice(datasource='vectorstore')

# %%
class Search_need(BaseModel):
    """Binary score for tell the necessity of web search."""

    binary_score: str = Field(
        description="Is necessary to do a web search on the query, 'yes' or 'no'"
    )
def need_of_search(query:str):
  structured_model_needs = model.with_structured_output(Search_need)

  # Prompt
  system = """You are an assistant responsible for determining whether a web search is necessary based on a user's query.
  You will receive a query and must decide if a web search is required. Provide a binary answer: 'yes' if the query cannot be answered without external information, or 'no' if it can be answered with available knowledge.
  Remember that is a continuos chat, so the user can use references that the final assistant will know
  Use your internal knowledge to answer straightforward questions and only suggest a search when it is absolutely necessary.
  Your response format should strictly follow this structure:
  - binary_score: 'yes' or 'no'

  Do not provide any other information or explanations."""

  need_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "User question: {query}"),
    ]
  )
  needs_router = need_prompt | structured_model_needs
  return needs_router.invoke({"query": query})

# %%
#Adaptar isso para o meu uso

### Retrieval Grader


# Data model
'''
class GradeDocuments(BaseModel):
    """Binary score for relevance check on retrieved documents."""

    binary_score: str = Field(
        description="Documents are relevant to the question, 'yes' or 'no'"
    )

structured_llm_grader = model.with_structured_output(GradeDocuments)

# Prompt
system = """You are a grader assessing relevance of a retrieved document to a user question. \n
    If the document contains keyword(s) or semantic meaning related to the user question, grade it as relevant. \n
    It does not need to be a stringent test. The goal is to filter out erroneous retrievals. \n
    Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question."""
grade_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Retrieved document: \n\n {document} \n\n User question: {query}"),
    ]
)
'''

def treshhold_docs(query: str, treshold:float = 0.8):
  topk, scores = retriever_with_score(query)
  for i in range(len(scores)):
    if scores[i] < treshold:
      topk[i] = ' '
  while ' ' in topk:
    topk.remove(' ')
  return topk

# %%
#Teste
'''retrieval_grader = grade_prompt | structured_llm_grader
question = "agent memory"
docs = retriever.get_relevant_documents(question)
doc_txt = docs[1].page_content
print(retrieval_grader.invoke({"query": question, "document": doc_txt}))
'''
#COLOCAR ISSO EM FUNÇÕES, COM OS MODELOS

# %%
# %pip install -qU duckduckgo-search langchain-community
from langchain_community.tools import DuckDuckGoSearchRun

def search_tool(query:str):
  web_search_tool = DuckDuckGoSearchRun()
  return web_search_tool.invoke(query)

# %%
### City retrieval

class City_search(BaseModel):
    """Binary score saying if the prompt has any city"""

    binary_score: str = Field(
        description="Does this query mention a city anywhere in the world, 'Yes' or 'No'"
    )
class City_name(BaseModel):
    """return the city name"""

    city: str = Field(
        description="Just the name of the city in a query"
    )

def city_func(query:str):
  structured_llm_grader = model.with_structured_output(City_search)

  # Prompt
  system = """You are a geography specialist who knows very well city names. Give a binary score 'yes' or 'no' score to indicate whether the user query mention any city in the world."""
  city_prompt = ChatPromptTemplate.from_messages(
      [
          ("system", system),
          ("human", "User query: {query}"),
      ]
  )
  retrieval_grader = city_prompt | structured_llm_grader

  response = retrieval_grader.invoke({"query": query})
  if response.binary_score == "no" or response.binary_score == "No":
    return response
  else:
    structured_llm_grader = model.with_structured_output(City_name)
    system2 = """You are a geography specialist who knows very well city names. In a query in which there is a city name for sure, just return this city name."""
    city_prompt2 = ChatPromptTemplate.from_messages(
        [
            ("system", system2),
            ("human", "User query: {query}"),
        ]
    )
    name = city_prompt | structured_llm_grader
    response2 = name.invoke({"query": query})
    response2 = response2.city
    docs = search_tool(response2)
    #web_results = "\n".join([d["content"] for d in docs])
    #web_results = Document(page_content=web_results)
    return docs

# %%
#Teste

query = "Quais são as melhores práticas para mitigar os efeitos das ilhas de calor urbanas em brumado?"
city_func(query)
# Out:
# brumado
# ...

# %%
def query_rewriter(query:str):
  system = """You a question re-writer that converts an input question to a better version that is optimized \n
      for vectorstore retrieval. Look at the input and try to reason about the underlying semantic intent / meaning."""
  re_write_prompt = ChatPromptTemplate.from_messages(
      [
          ("system", system),
          (
              "human",
              "Here is the initial query: \n\n {query} \n Formulate an improved question.",
          ),
      ]
  )

  question_rewriter = re_write_prompt | model | StrOutputParser()
  return question_rewriter.invoke({"query": query})

# %%
query_rewriter(query)
# Out:
# 'Quais estratégias eficazes podem ser implementadas em Brumado para reduzir os impactos das ilhas de calor urbanas?'

# %%
#Fazendo esse grafo:
from typing import List

from typing_extensions import TypedDict


class GraphState(TypedDict):
    """
    Represents the state of our graph.

    Attributes:
        query: query
        generation: LLM generation
        context: list of documents
        messages: list of preview messages
    """

    query: str
    generation: str
    context: List[str]
    messages: List[str]


    #Implementar a memoria com esse messages, ver se tenho que usar o message state

# %%
import uuid

from langchain_core.chat_history import InMemoryChatMessageHistory

chats_by_session_id = {}


def get_chat_history(session_id: str) -> InMemoryChatMessageHistory:
    chat_history = chats_by_session_id.get(session_id)
    if chat_history is None:
        chat_history = InMemoryChatMessageHistory()
        chats_by_session_id[session_id] = chat_history
    return chat_history

    #Posso usar usar pra implementar "no pelo"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e51ba2037965> in <cell line: 3>()
#       1 import uuid
#       2
# ----> 3 from langchain_core.chat_history import InMemoryChatMessageHistory
#       4
#       5 chats_by_session_id = {}
#
# ModuleNotFoundError: No module named 'langchain_core'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from langchain.schema import Document

###Nodes

def retrieve(state):
    """
    Retrieve documents

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, documents, that contains retrieved documents
    """
    print("---RETRIEVE---")
    query = state["query"]

    # Retrieval
    docs = retriever(query)
    context = [doc.page_content for doc in docs]
    return {"context": context, "query": query}


def generate(state):
    """
    Generate answer

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, generation, that contains LLM generation
    """
    print("---GENERATE---")
    query = state["query"]
    context = state.get("context", " ")
    messages = state.get("messages", " ")
    chat_history = get_chat_history(config["configurable"]["session_id"])
    if messages == " ":
      messages = list(chat_history.messages)
    else:
      messages = list(chat_history.messages) + messages

    # RAG generation

    generation = call_llm(query = query, context = context, memory = messages)
    chat_history.add_user_message(query)
    chat_history.add_ai_message(generation)  #Ver se isso não gera repetições e se adiciona certo
    return {"context": context, "query": query, "generation": generation, "messages": messages}
def same(state):

    print("---SAME---")
    query = state["query"]

    return {"query": query}


def transform_query(state):
    """
    Transform the query to produce a better question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates question key with a re-phrased question
    """

    print("---TRANSFORM QUERY---")
    query = state["query"]
    context = state["context"]

    # Re-write question
    better_query = query_rewriter(query)
    return {"context": context, "query": better_query}

def treshhold_check(state, treshold:float = 0.8):
    """
    Check the document scores and filter them based on a threshold.

    Args:
        state (dict): The current graph state containing query and threshold.

    Returns:
        state (dict): Updates 'top_docs' key with documents that passed the threshold.
    """

    print("---THRESHOLD CHECK---")
    query = state["query"]

    # Get top documents based on threshold
    top_docs = treshhold_docs(query, treshold)

    return {"query": query, "context": top_docs}

def web_search(state):
    """
    Web search based on the re-phrased question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates documents key with appended web results
    """

    print("---WEB SEARCH---")
    query = state["query"]

    # Web search
    web_results = search_tool(query)

    return {"context": web_results, "query": query}

def thereIs_city(state):
    """
    Web search based on the re-phrased question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates documents key with appended web results for the city
    """

    print("---WEB SEARCH FOR THE USER CITY---")
    query = state["query"]

    # Web search for the city
    web_results = city_func(query)

    return {"context": web_results, "query": query}


### Edges ###


def route_question(state):
    """
    Route question to web search or RAG.

    Args:
        state (dict): The current graph state

    Returns:
        str: Next node to call
    """

    print("---ROUTE QUESTION---")
    query = state["query"]
    source = router_func(query)
    if source.datasource == "web_search":
        print("---ROUTE QUESTION TO WEB SEARCH---")
        return "Need"
    elif source.datasource == "vectorstore":
        print("---ROUTE QUESTION TO RAG---")
        return "vectorstore"

def DoSearch(state):
    """
    Determine if a web search is needed based on the query and route accordingly.

    Args:
        state (dict): The current graph state containing the query.

    Returns:
        str: Next node to call ("web_search" or "generate").
    """

    print("---SEARCH NEED CHECK---")
    query = state["query"]

    # Use the need_of_search function to determine if a web search is necessary
    search_decision = need_of_search(query)

    # Extract the binary_score from the result
    binary_score = search_decision.binary_score

    # Route the question based on the search decision
    if binary_score == 'yes':
        print("---ROUTE QUESTION TO WEB SEARCH---")
        return "web_search"
    elif binary_score == 'no':
        print("---ROUTE QUESTION TO GENERATE---")
        return "generate"


def decide_to_generate(state):
    """
    Determines whether to generate an answer, or re-generate a question.

    Args:
        state (dict): The current graph state

    Returns:
        str: Binary decision for next node to call
    """

    print("---ASSESS TRESHOLD DOCUMENTS---")
    state["query"]
    filtered_documents = state["context"]

    if not filtered_documents:
        # All documents have been filtered check_relevance
        # We will re-generate a new query
        print(
            "---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, TRANSFORM QUERY---"
        )
        return "transform_query"
    else:
        # We have relevant documents, so generate answer
        print("---DECISION: GENERATE---")
        return "generate"

# %%
# !pip install langgraph -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.0/378.0 kB 26.6 MB/s eta 0:00:00

# %%
# !pip install langgraph-checkpoint-sqlite -q

# %%
from langgraph.graph import END, StateGraph, START
from langgraph.checkpoint.sqlite import SqliteSaver

#memory = SqliteSaver.from_conn_string(":memory:")

workflow = StateGraph(GraphState)

# Define the nodes
workflow.add_node("web_search", web_search)  # web search
#workflow.add_node("thereIs_city", thereIs_city)  #Ver como onde no fluxo vou encaixar isso (fazer como extra para o retriever ou extra para o web search)
workflow.add_node("retrieve", retrieve)  # retrieve
workflow.add_node("DoSearch", same)
workflow.add_node("treshhold_check", treshhold_check)  # grade documents
workflow.add_node("generate", generate)  # generatae
workflow.add_node("transform_query", transform_query)  # transform_query

# Build graph
workflow.add_conditional_edges(
    START,
    route_question,
    {
        "Need": "DoSearch",
        "vectorstore": "retrieve",
    },
)
workflow.add_conditional_edges(
    "DoSearch",
    DoSearch,
    {
        "web_search": "web_search",
        "generate": "generate",
    },
)
workflow.add_edge("web_search", "generate")
workflow.add_edge("retrieve", "treshhold_check")
workflow.add_conditional_edges(
    "treshhold_check",
    decide_to_generate,
    {
        "transform_query": "transform_query",
        "generate": "generate",
    },
)
workflow.add_edge("transform_query", "retrieve")
workflow.add_edge("generate", END)

# Compile
app = workflow.compile()

# %%
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))

# %%
from pprint import pprint

# Run
inputs = {
    "query": "Quais são as melhores práticas para mitigar os efeitos das ilhas de calor urbanas?"
}
for output in app.stream(inputs):
    for key, value in output.items():
        # Node
        pprint(f"Node '{key}':")
        # Optional: print full state at each node
        # pprint.pprint(value["keys"], indent=2, width=80, depth=None)
    pprint("\n---\n")

# Final generation
pprint(value["generation"])
# Out:
# ---ROUTE QUESTION---
# ---ROUTE QUESTION TO WEB SEARCH---
# ---WEB SEARCH---
# "Node 'web_search':"
# '\n---\n'
# ---GENERATE---
# "Node 'generate':"
# '\n---\n'
# ('Para mitigar os efeitos das ilhas de calor urbanas, é fundamental adotar uma '
#  'abordagem integrada que considere diversas práticas e estratégias. Aqui '
#  'estão algumas das melhores práticas recomendadas:\n'
#  '\n'
#  '1. **Aumento da Vegetação Urbana**: Plantar árvores e criar espaços verdes, '
#  'como parques e jardins verticais, ajuda a resfriar o ambiente através da '
#  'sombra e da evapotranspiração. A vegetação também melhora a qualidade do ar '
#  'e promove a biodiversidade.\n'
#  '\n'
#  '2. **Superfícies Reflexivas**: Utilizar materiais de construção com alta '
#  'refletância solar (como telhados brancos ou pavimentos permeáveis) pode '
#  'reduzir a absorção de calor. Isso diminui a temperatura das superfícies '
#  'urbanas e, consequentemente, a temperatura do ar.\n'
#  '\n'
# ...

# %%
from pprint import pprint

# Run
inputs = {
    "query": "Quais são as dificuldades climaticas que enfreto em Brumado na Bahia?"
}
config = {"configurable": {"thread_id": "58"}}
for output in app.stream(inputs, config):
    for key, value in output.items():
        # Node
        pprint(f"Node '{key}':")
        # Optional: print full state at each node
        # pprint.pprint(value["keys"], indent=2, width=80, depth=None)
    pprint("\n---\n")

# Final generation
pprint(value["generation"])
# Out:
# ---ROUTE QUESTION---
# ---ROUTE QUESTION TO RAG---
# ---RETRIEVE---
# "Node 'retrieve':"
# '\n---\n'
# ---THRESHOLD CHECK---
# ---ASSESS TRESHOLD DOCUMENTS---
# ---DECISION: GENERATE---
# "Node 'treshhold_check':"
# '\n---\n'
# ---GENERATE---
# "Node 'generate':"
# '\n---\n'
# ('Brumado, localizado no estado da Bahia, enfrenta diversas dificuldades '
#  'climáticas que podem impactar tanto a população quanto as atividades '
#  'econômicas da região. Abaixo estão algumas das principais dificuldades '
#  'climáticas que você deve considerar em seu planejamento:\n'
#  '\n'
#  '1. **Aumento da Temperatura**: As mudanças climáticas têm resultado em um '
#  'aumento das temperaturas em diversas regiões do Brasil, incluindo a Bahia. '
#  'Isso pode levar a um estresse hídrico, afetando a disponibilidade de água '
#  'para consumo e para atividades agrícolas.\n'
#  '\n'
#  '2. **Mudanças nos Padrões de Precipitação**: A previsão de aumento da '
# ...

# %%
inputs = {
    "query": "I'from Brumado"
}
session_id = uuid.uuid4()
config = {"configurable": {"session_id": session_id}}

for output in app.stream(inputs, config):
    for key, value in output.items():
        # Node
        pprint(f"Node '{key}':")
        # Optional: print full state at each node
        # pprint.pprint(value["keys"], indent=2, width=80, depth=None)
    pprint("\n---\n")
pprint(value["generation"])
# Final generation
# Out:
# ---ROUTE QUESTION---
# ---ROUTE QUESTION TO WEB SEARCH---
# ---SAME---
# ---SEARCH NEED CHECK---
# ---ROUTE QUESTION TO GENERATE---
# "Node 'DoSearch':"
# '\n---\n'
# ---GENERATE---
# "Node 'generate':"
# '\n---\n'
# ('Great to hear from you! As a city planner in Brumado, addressing climate '
#  'change is crucial for promoting sustainability and resilience in your '
#  'community. Here are some key considerations and strategies you might explore '
#  'in your planning:\n'
#  '\n'
#  '1. **Climate Vulnerability Assessment**: Begin by assessing the specific '
#  'climate vulnerabilities that Brumado faces, such as increased temperatures, '
#  'drought, or extreme weather events. This will help you understand the risks '
#  'and prioritize actions.\n'
#  '\n'
#  '2. **Green Infrastructure**: Incorporate green spaces, urban forests, and '
#  'green roofs into your urban planning. These elements can help reduce heat, '
#  'manage stormwater, and improve air quality.\n'
#  '\n'
# ...

# %%
inputs = {
    "query": "Which country my city is from?"
}

for output in app.stream(inputs, session_id):
    for key, value in output.items():
        # Node
        pprint(f"Node '{key}':")
        # Optional: print full state at each node
        # pprint.pprint(value["keys"], indent=2, width=80, depth=None)
    pprint("\n---\n")
pprint(value["generation"])
# Final generation
# Out:
# ---ROUTE QUESTION---
# ---ROUTE QUESTION TO WEB SEARCH---
# ---SAME---
# ---SEARCH NEED CHECK---
# ---ROUTE QUESTION TO WEB SEARCH---
# "Node 'DoSearch':"
# '\n---\n'
# ---WEB SEARCH---
# "Node 'web_search':"
# '\n---\n'
# ---GENERATE---
# "Node 'generate':"
# '\n---\n'
# ('You mentioned earlier that you are from Brumado, which is a city in Brazil. '
#  'If you have any specific questions or need assistance with climate change '
#  'planning in Brumado, feel free to ask!')

# %%
def chat(session_id:uuid.UUID, query: str = None):
  if query == None:
    query = str(input("Você: "))
  inputs = {
    "query":  query
  }

  for output in app.stream(inputs, session_id):
      for key, value in output.items():
          # Node
          pprint(f"Node '{key}':")
          # Optional: print full state at each node
          # pprint.pprint(value["keys"], indent=2, width=80, depth=None)
      print("\n---\n")
  print(value["generation"])

# %%
def chatbot():
    session_id = uuid.uuid4()
    print("Bem-vindo ao chatbot! Digite 'sair' para encerrar a conversa.")

    while True:
        query = str(input("Você: "))
        if query.lower() == "sair":
            print("Conversa encerrada. Até mais!")
            break
        chat(session_id, query)

# %%
session_id = uuid.uuid4()
session_id
# Out:
# UUID('5d5208bd-d420-4c74-a506-54da6c0e8bf1')

# %% [markdown]
# Codigos para usar ps:

# %%
def grade_documents(state):
    """
    Determines whether the retrieved documents are relevant to the question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates documents key with only filtered relevant documents
    """

    print("---CHECK DOCUMENT RELEVANCE TO QUESTION---")
    question = state["question"]
    documents = state["documents"]

    # Score each doc
    filtered_docs = []
    for d in documents:
        score = retrieval_grader.invoke(
            {"question": question, "context": d.page_content}
        )
        grade = score.binary_score
        if grade == "yes":
            print("---GRADE: DOCUMENT RELEVANT---")
            filtered_docs.append(d)
        else:
            print("---GRADE: DOCUMENT NOT RELEVANT---")
            continue
    return {"documents": filtered_docs, "question": question}  #ADAPTAR

# %%
'''def grade_generation_v_documents_and_question(state):
    """
    Determines whether the generation is grounded in the document and answers question.

    Args:
        state (dict): The current graph state

    Returns:
        str: Decision for next node to call
    """

    print("---CHECK HALLUCINATIONS---")
    query = state["query"]
    context = state["context"]
    generation = state["generation"]

    score = hallucination_grader.invoke(
        {"context": context, "generation": generation}
    )
    grade = score.binary_score

    # Check hallucination #TIRAR ISSO
    if grade == "yes":
        print("---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---")
        # Check question-answering
        print("---GRADE GENERATION vs QUESTION---")
        score = answer_grader.invoke({"question": question, "generation": generation}) #TIRAR ISSO
        grade = score.binary_score
        if grade == "yes":
            print("---DECISION: GENERATION ADDRESSES QUESTION---")
            return "useful"
        else:
            print("---DECISION: GENERATION DOES NOT ADDRESS QUESTION---")
            return "not useful"
    else:
        print("---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---")
        return "not supported"
'''
